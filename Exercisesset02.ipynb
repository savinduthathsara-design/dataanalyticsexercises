# %% [markdown]
# ## **Pandas Exercise set**

# %% [markdown]
# ## **Exercise 01**
# ---

# %% [markdown]
# ### 01. Import pandas and load dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

np.set_printoptions(suppress=True)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df = pd.read_csv("exercises2_datafiles/loans.csv")

# prining the head of the data 
df.head
# Out:
# <bound method NDFrame.head of                                     Loan ID  Loan Status  Current Loan Amount  \
# 0      14dd8831-6af5-400b-83ec-68e61888a048   Fully Paid            445412.00
# 1      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26   Fully Paid          99999999.00
# 2      77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a   Fully Paid            347666.00
# 3      89d8cb0c-e5c2-4f54-b056-48a645c543dd  Charged Off            206602.00
# 4      273581de-85d8-4332-81a5-19b04ce68666   Fully Paid            217646.00
# ...                                     ...          ...                  ...
# 70316  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0   Fully Paid            210584.00
# 70317  06eba04f-58fc-424a-b666-ed72aa008900   Fully Paid          99999999.00
# 70318  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7   Fully Paid            103136.00
# 70319  81ab928b-d1a5-4523-9a3c-271ebb01b4fb   Fully Paid            530332.00
# 70320  c63916c6-6d46-47a9-949a-51d09af4414f   Fully Paid          99999999.00
#
#              Term  Credit Score  Annual Income Home Ownership  \
# 0      Short Term        709.00     1167493.00  Home Mortgage
# 1      Short Term        741.00     2231892.00       Own Home
# 2       Long Term        721.00      806949.00       Own Home
# 3      Short Term       7290.00      896857.00  Home Mortgage
# 4      Short Term        730.00     1184194.00  Home Mortgage
# ...           ...           ...            ...            ...
# 70316  Short Term        719.00      783389.00  Home Mortgage
# 70317  Short Term        732.00     1289416.00           Rent
# 70318  Short Term        742.00     1150545.00           Rent
# 70319  Short Term        746.00     1717524.00           Rent
# 70320  Short Term        743.00      935180.00       Own Home
#
#                   Purpose  Monthly Debt  Years of Credit History  \
# 0       Home Improvements       5214.74                    17.20
# 1      Debt Consolidation      29200.53                    14.90
# 2      Debt Consolidation       8741.90                    12.00
# 3      Debt Consolidation      16367.74                    17.30
# 4      Debt Consolidation      10855.08                    19.60
# ...                   ...           ...                      ...
# 70316               Other       3727.61                    17.40
# 70317  Debt Consolidation      13109.05                     9.40
# 70318  Debt Consolidation       7315.57                    18.80
# 70319  Debt Consolidation       9890.07                    15.00
# 70320  Debt Consolidation       9118.10                    13.00
#
#        Number of Open Accounts  Number of Credit Problems  \
# 0                         6.00                       1.00
# 1                        18.00                       1.00
# 2                         9.00                       0.00
# 3                         6.00                       0.00
# 4                        13.00                       1.00
# ...                        ...                        ...
# 70316                     6.00                       0.00
# 70317                    22.00                       0.00
# 70318                    12.00                       1.00
# 70319                     8.00                       0.00
# 70320                     4.00                       1.00
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies
# 0                   228190.00            416746.00          1.00
# 1                   297996.00            750090.00          0.00
# 2                   256329.00            386958.00          0.00
# 3                   215308.00            272448.00          0.00
# 4                   122170.00            272052.00          1.00
# ...                       ...                  ...           ...
# 70316                  456.00            259160.00          0.00
# 70317               153045.00            509234.00          0.00
# 70318               109554.00            537548.00          1.00
# 70319               404225.00            738254.00          0.00
# 70320                45600.00             91014.00          1.00
#
# [70321 rows x 15 columns]>

# %% [markdown]
# ### 02. remove unrealistically large loans

# %%
df = df[df["Current Loan Amount"] < 99999999]

df.head
# Out:
# <bound method NDFrame.head of                                     Loan ID  Loan Status  Current Loan Amount  \
# 0      14dd8831-6af5-400b-83ec-68e61888a048   Fully Paid            445412.00
# 2      77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a   Fully Paid            347666.00
# 3      89d8cb0c-e5c2-4f54-b056-48a645c543dd  Charged Off            206602.00
# 4      273581de-85d8-4332-81a5-19b04ce68666   Fully Paid            217646.00
# 5      8af915d9-9e91-44a0-b5a2-564a45c12089   Fully Paid            548746.00
# ...                                     ...          ...                  ...
# 70313  3b2a09bb-3467-4d2f-bd8f-260fdc5760be   Fully Paid            179454.00
# 70314  38530a21-5a57-47f5-9aaa-b4475b1db345   Fully Paid            781022.00
# 70316  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0   Fully Paid            210584.00
# 70318  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7   Fully Paid            103136.00
# 70319  81ab928b-d1a5-4523-9a3c-271ebb01b4fb   Fully Paid            530332.00
#
#              Term  Credit Score  Annual Income Home Ownership  \
# 0      Short Term        709.00     1167493.00  Home Mortgage
# 2       Long Term        721.00      806949.00       Own Home
# 3      Short Term       7290.00      896857.00  Home Mortgage
# 4      Short Term        730.00     1184194.00  Home Mortgage
# 5      Short Term        678.00     2559110.00           Rent
# ...           ...           ...            ...            ...
# 70313  Short Term        708.00     1356068.00  Home Mortgage
# 70314  Short Term        741.00     2582404.00  Home Mortgage
# 70316  Short Term        719.00      783389.00  Home Mortgage
# 70318  Short Term        742.00     1150545.00           Rent
# 70319  Short Term        746.00     1717524.00           Rent
#
#                   Purpose  Monthly Debt  Years of Credit History  \
# 0       Home Improvements       5214.74                    17.20
# 2      Debt Consolidation       8741.90                    12.00
# 3      Debt Consolidation      16367.74                    17.30
# 4      Debt Consolidation      10855.08                    19.60
# 5      Debt Consolidation      18660.28                    22.60
# ...                   ...           ...                      ...
# 70313  Debt Consolidation      22318.54                    22.70
# 70314  Debt Consolidation      51648.08                    26.30
# 70316               Other       3727.61                    17.40
# 70318  Debt Consolidation       7315.57                    18.80
# 70319  Debt Consolidation       9890.07                    15.00
#
#        Number of Open Accounts  Number of Credit Problems  \
# 0                         6.00                       1.00
# 2                         9.00                       0.00
# 3                         6.00                       0.00
# 4                        13.00                       1.00
# 5                         4.00                       0.00
# ...                        ...                        ...
# 70313                    25.00                       0.00
# 70314                    25.00                       0.00
# 70316                     6.00                       0.00
# 70318                    12.00                       1.00
# 70319                     8.00                       0.00
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies
# 0                   228190.00            416746.00          1.00
# 2                   256329.00            386958.00          0.00
# 3                   215308.00            272448.00          0.00
# 4                   122170.00            272052.00          1.00
# 5                   437171.00            555038.00          0.00
# ...                       ...                  ...           ...
# 70313               387410.00           1705616.00          0.00
# 70314               669180.00           2299198.00          0.00
# 70316                  456.00            259160.00          0.00
# 70318               109554.00            537548.00          1.00
# 70319               404225.00            738254.00          0.00
#
# [58893 rows x 15 columns]>

# %% [markdown]
# ### 03. loans that have highest credit balance

# %%
df.nlargest(5, "Current Loan Amount")
# Out:
#                                     Loan ID Loan Status  Current Loan Amount  \
# 16422  4fed402f-4298-4f5c-8d30-05b1f1819c00  Fully Paid            789250.00
# 32147  b7923e12-395b-49d6-97ee-ca0ed25b65c2  Fully Paid            789250.00
# 35079  a572e23e-fc67-4d7a-92d0-3cad85ec0a47  Fully Paid            789184.00
# 36039  f95fe414-2e62-4d41-82be-e162e5715fef  Fully Paid            789184.00
# 36417  8d59aa00-d111-4439-9b32-82cc5ab5b940  Fully Paid            789184.00
#
#              Term  Credit Score  Annual Income Home Ownership  \
# 16422   Long Term        672.00     1752750.00           Rent
# 32147  Short Term        721.00     8054480.00  Home Mortgage
# 35079   Long Term        685.00     4381457.00  Home Mortgage
# 36039   Long Term        713.00     2239416.00  Home Mortgage
# 36417   Long Term        716.00     1596798.00  Home Mortgage
#
#                   Purpose  Monthly Debt  Years of Credit History  \
# 16422  Debt Consolidation      29212.50                     8.50
# 32147  Debt Consolidation     114105.07                    31.40
# 35079  Debt Consolidation      46370.26                    17.80
# 36039  Debt Consolidation      44228.20                    17.30
# 36417  Debt Consolidation      44710.23                    28.50
#
#        Number of Open Accounts  Number of Credit Problems  \
# 16422                    11.00                       0.00
# 32147                    21.00                       0.00
# 35079                    17.00                       0.00
# 36039                    17.00                       0.00
# 36417                    15.00                       0.00
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies
# 16422               971508.00           1538856.00          0.00
# 32147              1826147.00           2405568.00          0.00
# 35079               694089.00           1096414.00          0.00
# 36039               632263.00           1247180.00          0.00
# 36417               921139.00           1760044.00          0.00

# %% [markdown]
# ### 04. Loans with smallest annual income

# %%
df.nsmallest(5, "Annual Income")
# Out:
#                                     Loan ID  Loan Status  Current Loan Amount  \
# 48729  fdda52f3-bbfa-45da-80b5-2bd9b68638ed  Charged Off             30448.00
# 38169  9ed28b3a-c3a9-4ae4-93e6-3de7ff42f64e   Fully Paid             61490.00
# 7624   241e16a3-c198-4d8e-8dad-c927fd7c7d24   Fully Paid             34342.00
# 18719  1596dd1e-d8ba-45eb-b4a8-ee75736b66b6   Fully Paid             47894.00
# 22489  c28d26b0-a805-4e71-b389-f9fc1c9d8bb2   Fully Paid             46860.00
#
#              Term  Credit Score  Annual Income Home Ownership  \
# 48729  Short Term        736.00       76627.00           Rent
# 38169  Short Term        662.00       81092.00           Rent
# 7624   Short Term        715.00      111245.00       Own Home
# 18719  Short Term        688.00      130150.00       Own Home
# 22489  Short Term        714.00      134881.00           Rent
#
#                     Purpose  Monthly Debt  Years of Credit History  \
# 48729    Debt Consolidation        845.50                     9.50
# 38169  Educational Expenses          0.00                    11.00
# 7624                  Other        463.60                    29.70
# 18719                 Other       2971.41                    21.30
# 22489    Debt Consolidation       1641.22                     6.00
#
#        Number of Open Accounts  Number of Credit Problems  \
# 48729                     8.00                       0.00
# 38169                     6.00                       0.00
# 7624                      3.00                       0.00
# 18719                     3.00                       0.00
# 22489                     4.00                       0.00
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies
# 48729                28177.00            147598.00          0.00
# 38169                    0.00                 0.00          0.00
# 7624                  6840.00            264044.00          0.00
# 18719               100510.00            191730.00          0.00
# 22489                43491.00             89298.00          0.00

# %% [markdown]
# ### 05. Min, max, mean and quantiles (25%, 50%, 75%)

# %%
df["Current Loan Amount"].describe()
# Out:
# count    58893.00
# mean    312122.30
# std     185174.86
# min      15422.00
# 25%     172876.00
# 50%     267454.00
# 75%     432432.00
# max     789250.00
# Name: Current Loan Amount, dtype: float64

# %%
print('Min:  ', df['Current Loan Amount'].min())
print('Max:  ', df['Current Loan Amount'].max())
print('Mean: ', df['Current Loan Amount'].mean())
print('25%:  ', df['Current Loan Amount'].quantile(0.25))
print('50%:  ', df['Current Loan Amount'].quantile(0.50))
print('75%:  ', df['Current Loan Amount'].quantile(0.75))
# Out:
# Min:   15422.0
# Max:   789250.0
# Mean:  312122.29711510707
# 25%:   172876.0
# 50%:   267454.0
# 75%:   432432.0

# %% [markdown]
# ### 6. Create a new field: Actual Annual Income

# %%
df["Actual Annual Income"] = df["Annual Income"] - (12 * df["Monthly Debt"])

df[["Annual Income", "Monthly Debt", "Actual Annual Income"]].head(10)
# Out:
#     Annual Income  Monthly Debt  Actual Annual Income
# 0      1167493.00       5214.74            1104916.12
# 2       806949.00       8741.90             702046.20
# 3       896857.00      16367.74             700444.12
# 4      1184194.00      10855.08            1053933.04
# 5      2559110.00      18660.28            2335186.64
# 6      1454735.00      39277.75             983402.00
# 10      693234.00      14211.24             522699.12
# 11     1821967.00      17612.24            1610620.12
# 12     1791738.00       2478.55            1761995.40
# 13     1133274.00       9632.81            1017680.28

# %% [markdown]
# ### 07. Long term loans quantity

# %%
count = df["Term"].value_counts()
print(count)
print(f"Number of long term loans : {count.get("Long Term")}")
# Out:
# Term
# Short Term    42141
# Long Term     16752
# Name: count, dtype: int64
# Number of long term loans : 16752

# %% [markdown]
# ### 08. 3 most common loan purposes

# %%
# replace the "other" with "Other" 
df["Purpose"] = df["Purpose"].replace("other", "Other")

# get all purposes 
purpose_count = df["Purpose"].value_counts()
print(purpose_count)

# top 3 most common purposes
print(f"\n {purpose_count.head(3)}")
# Out:
# Purpose
# Debt Consolidation      46474
# Other                    5437
# Home Improvements        3397
# Business Loan             946
# Buy a Car                 743
# Medical Bills             645
# Buy House                 396
# major_purchase            215
# Take a Trip               203
# small_business            175
# moving                     90
# wedding                    57
# Educational Expenses       55
# vacation                   54
# renewable_energy            6
# Name: count, dtype: int64
#
#  Purpose
# Debt Consolidation    46474
# Other                  5437
# Home Improvements      3397
# Name: count, dtype: int64

# %% [markdown]
# ### Extra task: Distribution of Number of Credit Problems

# %%
credit_problems = df["Number of Credit Problems"].value_counts()
print(credit_problems)
# Out:
# Number of Credit Problems
# 0.00    50788
# 1.00     7014
# 2.00      753
# 3.00      216
# 4.00       72
# 5.00       33
# 6.00       10
# 7.00        5
# 8.00        2
# Name: count, dtype: int64

# %%
# Findings:
# The majority of borrowers have 0 credit problems.
# Very few borrowers have 2 or more problems. This means that most customers have clean credit histories.

# %% [markdown]
# ### 09. Unique Home Ownership options

# %%
unique_values = df["Home Ownership"].unique()
print(unique_values)
# Out:
# <StringArray>
# ['Home Mortgage', 'Own Home', 'Rent']
# Length: 3, dtype: str

# %% [markdown]
# ### Extra task: How many loaners have more than 1 bankruptcy

# %%
bankruptcy = df[df["Bankruptcies"] > 1]
print(f"loaners have more than 1 bankruptcy : {len(bankruptcy)}")
# Out:
# loaners have more than 1 bankruptcy : 305

# %% [markdown]
# ### Extra task: How many Short Term loans are for Home Improvements?

# %%
# filter short term loans 
short_term = df[df['Term'] == 'Short Term']

# short term loan purposes
short_term_purposes = short_term["Purpose"].value_counts()
print(short_term_purposes)

# home improvement purpose
home_improvement_count = short_term_purposes.get('Home Improvements')
print(f"\nShort term loans for home improvements: {home_improvement_count}")
# Out:
# Purpose
# Debt Consolidation      32803
# Other                    4302
# Home Improvements        2324
# Business Loan             668
# Buy a Car                 571
# Medical Bills             524
# Buy House                 274
# Take a Trip               176
# major_purchase            153
# small_business            120
# moving                     74
# vacation                   51
# Educational Expenses       49
# wedding                    47
# renewable_energy            5
# Name: count, dtype: int64
#
# Short term loans for home improvements: 2324

# %% [markdown]
# ### Extra task: Correlation Analysis

# %%
# Option A: Annual Income vs Number of Open Accounts 
corr_a = df['Annual Income'].corr(df['Number of Open Accounts'])
print(f'Correlation (Annual Income vs Number of Open Accounts): {corr_a:.4f}')
# Out:
# Correlation (Annual Income vs Number of Open Accounts): 0.1376

# %% [markdown]
# **Annual Income vs Number of Open Accounts:** A weak correlation suggests that having more open accounts does not strongly correlate with higher or lower income.

# %%
# Option B: Number of Credit Problems vs Bankruptcies 
corr_b = df['Number of Credit Problems'].corr(df['Bankruptcies'])
print(f'Correlation (Number of Credit Problems vs Bankruptcies): {corr_b:.4f}')
# Out:
# Correlation (Number of Credit Problems vs Bankruptcies): 0.7630

# %% [markdown]
# **Number of Credit Problems vs Bankruptcies:** this correlation would confirm that borrowers with more credit problems also tend to have more bankruptcies. This is true because bankruptcies are one of the most severe forms of credit problems.

# %% [markdown]
# ## **Exercise 02**
# ---

# %%
# load the data set
df = pd.read_csv("exercises2_datafiles/purchases.csv")

df.head()
# Out:
#   Purchase Date Purchase Order Number Acquisition Type    Acquisition Method  \
# 0    08/31/2012            4500149558      Other Goods    Formal Competitive
# 1    10/18/2012            4500156192      Other Goods  Informal Competitive
# 2    10/17/2012            4500156124      Other Goods   Fair and Reasonable
# 3    10/24/2012              S2556056      Other Goods  Informal Competitive
# 4    11/14/2012            4500159228      Other Goods  Informal Competitive
#
#                                  Department Name              Supplier Name  \
# 0  Corrections and Rehabilitation, Department of        Fresno Produce Inc.
# 1  Corrections and Rehabilitation, Department of            PETER GIAMMANCO
# 2              Correctional Health Care Services            OSHA Review Inc
# 3              Parks & Recreation, Department of               Agco Hay LLC
# 4  Corrections and Rehabilitation, Department of  Prison Industry Authority
#
#   Item Name         Item Description  Quantity Unit Price  Total Price  \
# 0  JALAPENO                 JALAPENO     40.00      $0.60        24.00
# 1   produce      red apples, banana,      1.00  $12587.05     12587.05
# 2  magazine                 magazine      1.00    $199.00       199.00
# 3       hay     Bale's of rice straw   1000.00      $4.95      4950.00
# 4    COFFEE  INSTANT COFFEE AND BULK  14686.50      $1.00     14686.50
#
#     Commodity Title           Class Title      Family Title  \
# 0  Jalapeno peppers               Peppers  Fresh vegetables
# 1    Ida red apples                Apples      Fresh fruits
# 2         Magazines  Printed publications     Printed media
# 3               Hay        Livestock feed       Animal feed
# 4            Coffee        Coffee and tea         Beverages
#
#                                        Segment Title
# 0                 Food Beverage and Tobacco Products
# 1                 Food Beverage and Tobacco Products
# 2                                 Published Products
# 3  Live Plant and Animal Material and Accessories...
# 4                 Food Beverage and Tobacco Products

# %% [markdown]
# ### 01. Total price sum for Purchase Order Number 018H2015

# %%
order_018 = df[df["Purchase Order Number"] == "018H2015"]

# finding the total price 
total_price = order_018["Total Price"].sum()

print(f"Total sum of the order number 018H2015: ${total_price}")
# Out:
# Total sum of the order number 018H2015: $1245.0400000000002

# %% [markdown]
# ### 02. Item name and description for Purchase Order Number 3176273

# %%
order_317 = df[df["Purchase Order Number"] == "3176273"]

order_317[["Purchase Order Number", "Item Name", "Item Description"]]
# Out:
#     Purchase Order Number   Item Name Item Description
# 103               3176273  PC Desktop   HP Prodesk 600

# %% [markdown]
# ### 03. How many purchases in 2013

# %%
# convert purchase data to datetime 
df["Purchase Date"] = pd.to_datetime(df["Purchase Date"])

# filter data with 2013 purchases
purchases_2013 = df[df["Purchase Date"].dt.year == 2013]

purchases_2013_count = len(purchases_2013)

print(f"2013 purchases: {purchases_2013_count}")
# Out:
# 2013 purchases: 33907

# %% [markdown]
# ### 04. Top 5 most common Departments

# %%
top5_departments = df["Department Name"].value_counts()
top5_departments.head(5)
# Out:
# Department Name
# Corrections and Rehabilitation, Department of    10858
# Correctional Health Care Services                 6591
# Water Resources, Department of                    4566
# Forestry and Fire Protection, Department of       4513
# State Hospitals, Department of                    4258
# Name: count, dtype: int64

# %% [markdown]
# ### Extra Task : Top 3 Departments by total money spent

# %%
# Group by Department Name and sum the Total Price, then get top 3
top3_departments = df.groupby("Department Name")["Total Price"].sum()
top3_departments.head(3)
# Out:
# Department Name
# Administrative Law, Office of            50000.00
# African American Museum, California     103122.44
# Aging, Department of                  82834987.10
# Name: Total Price, dtype: float64

# %% [markdown]
# ### 05. replace $ sign in Unit Price column and convert to float

# %%
# remove $ sign
df["Unit Price"] = df["Unit Price"].str.replace("$", "")

# convert to float value
df["Unit Price"] = pd.to_numeric(df["Unit Price"])

df["Unit Price"].head()
# Out:
# 0       0.60
# 1   12587.05
# 2     199.00
# 3       4.95
# 4       1.00
# Name: Unit Price, dtype: float64

# %% [markdown]
# ### Extra task: Purchases were IT Goods with Total Price > $50,000?

# %%
it_products_50k = df[(df["Acquisition Type"] == "IT Goods") & (df["Total Price"] > 50000)]

it_products_50k = len(it_products_50k)

print(f"IT products with total price more than 50k: {it_products_50k} ")
# Out:
# IT products with total price more than 50k: 698

# %% [markdown]
# ### Extra task: IT related purchases

# %%
# IT related types 
IT_types = ["IT Goods", "IT Services", "IT Telecommunications"]

# filter IT related purchases 
IT_related = df[df["Acquisition Type"].isin(IT_types)]

# count the purchases 
IT_related = len(IT_related)

print(f"Total number of purchases that are IT related: {IT_related}")
# Out:
# Total number of purchases that are IT related: 9517

# %% [markdown]
# ### **Advance extra task**

# %% [markdown]
# ### filter purchses that have total price of 0 or less

# %%
df_filter = df[df["Total Price"] > 0]

# %% [markdown]
# ### Group by sum of total price

# %%
# I used AI to get the values by ascending order 
groupby_sum = df_filter.groupby("Acquisition Type")["Total Price"].sum()
groupby_sum = groupby_sum.sort_values(ascending=False)

print("Sum of total price by acquisition type:")
groupby_sum
# Out:
# Sum of total price by acquisition type:
# Acquisition Type
# Other Services          30559366139.50
# IT Services              1156961015.50
# Other Goods              1033809348.06
# IT Goods                  213609124.36
# IT Telecommunications        307903.39
# Name: Total Price, dtype: float64

# %% [markdown]
# ### Group by mean of total price

# %%
groupby_mean = df_filter.groupby("Acquisition Type")["Total Price"].mean()
groupby_mean = groupby_mean.sort_values(ascending=False)
print("mean of total price by acquisition type:")
groupby_mean
# Out:
# mean of total price by acquisition type:
# Acquisition Type
# Other Services          2484299.34
# IT Services              684997.64
# IT Telecommunications     51317.23
# IT Goods                  29074.33
# Other Goods               26151.20
# Name: Total Price, dtype: float64

# %% [markdown]
# ### Two acquisition types have the largest sums and means

# %%
groupby_sum.head(2)
# Out:
# Acquisition Type
# Other Services   30559366139.50
# IT Services       1156961015.50
# Name: Total Price, dtype: float64

# %%
groupby_mean.head(2)
# Out:
# Acquisition Type
# Other Services   2484299.34
# IT Services       684997.64
# Name: Total Price, dtype: float64

# %% [markdown]
# #### Both the largest SUM and largest MEAN belong to: "Other Services"
# #### 2nd largest SUM and largest MEAN belong to: "IT Services"

# %% [markdown]
# ## **Exercise 03**
# ---

# %%
# load the dataset 
df = pd.read_csv("exercises2_datafiles/salaries_india.csv")

df.head()
# Out:
#    Row ID                     Company Name Rating          Job Title  \
# 0   79417                        Unacademy   Good  Android Developer
# 1   79419           Appoids Tech Solutions   Good  Android Developer
# 2   79424  Endeavour Software Technologies   Good  Android Developer
# 3   79427                            Wibmo   Good  Android Developer
# 4   79429                       Bookmyshow   Good  Android Developer
#
#       Salary  Salaries Reported   Location Employment Status Job Roles
# 0 2046000.00                  3  Bangalore         Full Time    Mobile
# 1 1227600.00                  3  Bangalore         Full Time    Mobile
# 2 1227600.00                  3  Bangalore         Full Time    Mobile
# 3 1841400.00                  2  Bangalore         Full Time    Mobile
# 4 1227600.00                  2  Bangalore         Full Time    Mobile

# %% [markdown]
# ### 01. Drop Unnecessary Columns

# %%
df = df.drop(columns=["Row ID", "Job Title"])
df.head()
# Out:
#                       Company Name Rating     Salary  Salaries Reported  \
# 0                        Unacademy   Good 2046000.00                  3
# 1           Appoids Tech Solutions   Good 1227600.00                  3
# 2  Endeavour Software Technologies   Good 1227600.00                  3
# 3                            Wibmo   Good 1841400.00                  2
# 4                       Bookmyshow   Good 1227600.00                  2
#
#     Location Employment Status Job Roles
# 0  Bangalore         Full Time    Mobile
# 1  Bangalore         Full Time    Mobile
# 2  Bangalore         Full Time    Mobile
# 3  Bangalore         Full Time    Mobile
# 4  Bangalore         Full Time    Mobile

# %% [markdown]
# ### 02. Explore high salaries and remove outliers

# %%
# top 20 largest salaries 
print("Top 20 salaries:")
df["Salary"].nlargest(20)
# Out:
# Top 20 salaries:
# 6585   9284422.50
# 6561   8644117.50
# 8526   8421043.50
# 8229   8109153.00
# 8430   8109153.00
# 6575   8010090.00
# 6581   8010090.00
# 6583   8010090.00
# 6584   8010090.00
# 6542   8003812.50
# 6574   8003812.50
# 8491   7803378.00
# 8248   7797262.50
# 6565   7733880.00
# 6571   7733880.00
# 6572   7733880.00
# 6573   7733880.00
# 6596   7733880.00
# 6551   7683660.00
# 7978   7534296.00
# Name: Salary, dtype: float64

# %%
# Histogram to visualise salary distribution
# I used AI to learn how to create proper histogram with more visually pleasing 
df["Salary"].hist(bins=60, edgecolor= "white")
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Count")
plt.show()

# %%
# Decision: Salaries above 4,000,000 appears to be outliers 
print(f"Dataset without removel of data: {df.shape}")

cutoff_salaries = 4000000

# removing the ouliers
df = df[df["Salary"] <= cutoff_salaries]

print(f"Dataset after removing outliers: {df.shape}")
# Out:
# Dataset without removel of data: (10787, 7)
# Dataset after removing outliers: (10050, 7)

# %%
# Histogram after removing outliers 
df["Salary"].hist(bins=60, edgecolor= "white")
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### 03. Encode categorical variables

# %%
# before encoding "Employment status"
df["Employment Status"].value_counts()
# Out:
# Employment Status
# Full Time    9489
# Intern        561
# Name: count, dtype: int64

# %%
#Binary: employment status 
df["Employment Status"] = LabelEncoder().fit_transform(df['Employment Status'])

# "Full time" = 0, "Intern" = 1
df["Employment Status"].value_counts()
# Out:
# Employment Status
# 0    9489
# 1     561
# Name: count, dtype: int64

# %%
# before encoding "Rating"
df["Rating"].value_counts()
# Out:
# Rating
# Good         7641
# Excellent    1156
# Average      1151
# Poor           78
# Bad            24
# Name: count, dtype: int64

# %%
# Ordinal: Rating 
rating_order = {"Bad": 1, "Poor": 2, "Average": 3, "Good": 4, "Excellent": 5}
df["Rating"] = df["Rating"].map(rating_order)

df["Rating"].value_counts()
# Out:
# Rating
# 4    7641
# 5    1156
# 3    1151
# 2      78
# 1      24
# Name: count, dtype: int64

# %%
# Before the nominal catagories 
df.head(3)
# Out:
#                       Company Name  Rating     Salary  Salaries Reported  \
# 0                        Unacademy       4 2046000.00                  3
# 1           Appoids Tech Solutions       4 1227600.00                  3
# 2  Endeavour Software Technologies       4 1227600.00                  3
#
#     Location  Employment Status Job Roles
# 0  Bangalore                  0    Mobile
# 1  Bangalore                  0    Mobile
# 2  Bangalore                  0    Mobile

# %%
# Nominal: "Job Roles" and "Location"
df = pd.get_dummies(df, columns=['Job Roles', 'Location'], drop_first=False)

# after nominal catagories
df.head(3)
# Out:
#                       Company Name  Rating     Salary  Salaries Reported  \
# 0                        Unacademy       4 2046000.00                  3
# 1           Appoids Tech Solutions       4 1227600.00                  3
# 2  Endeavour Software Technologies       4 1227600.00                  3
#
#    Employment Status  Job Roles_Backend  Job Roles_Full stack  \
# 0                  0              False                 False
# 1                  0              False                 False
# 2                  0              False                 False
#
#    Job Roles_Mobile  Job Roles_Web  Location_Bangalore  Location_Chennai  \
# 0              True          False                True             False
# 1              True          False                True             False
# 2              True          False                True             False
#
#    Location_Hyderabad  Location_New Delhi  Location_Pune
# 0               False               False          False
# 1               False               False          False
# 2               False               False          False

# %% [markdown]
# ### 04. Correlation Matrix

# %%
df.corr(numeric_only=True)
# df.corr(method="spearman", numeric_only=True)
# Out:
#                       Rating  Salary  Salaries Reported  Employment Status  \
# Rating                  1.00    0.18              -0.01               0.02
# Salary                  0.18    1.00               0.08              -0.06
# Salaries Reported      -0.01    0.08               1.00               0.00
# Employment Status       0.02   -0.06               0.00               1.00
# Job Roles_Backend       0.01   -0.05              -0.06              -0.08
# Job Roles_Full stack   -0.02    0.25               0.14               0.18
# Job Roles_Mobile        0.00   -0.17              -0.07              -0.10
# Job Roles_Web           0.02   -0.09              -0.04              -0.04
# Location_Bangalore     -0.03    0.30               0.04               0.03
# Location_Chennai        0.01   -0.19              -0.02              -0.03
# Location_Hyderabad     -0.01    0.15              -0.00              -0.01
# Location_New Delhi      0.03   -0.26              -0.01               0.02
# Location_Pune           0.00   -0.11              -0.02              -0.02
#
#                       Job Roles_Backend  Job Roles_Full stack  \
# Rating                             0.01                 -0.02
# Salary                            -0.05                  0.25
# Salaries Reported                 -0.06                  0.14
# Employment Status                 -0.08                  0.18
# Job Roles_Backend                  1.00                 -0.45
# Job Roles_Full stack              -0.45                  1.00
# Job Roles_Mobile                  -0.30                 -0.46
# Job Roles_Web                     -0.21                 -0.32
# Location_Bangalore                 0.08                 -0.18
# Location_Chennai                   0.15                 -0.02
# Location_Hyderabad                 0.11                  0.04
# Location_New Delhi                -0.19                  0.08
# Location_Pune                     -0.16                  0.15
#
#                       Job Roles_Mobile  Job Roles_Web  Location_Bangalore  \
# Rating                            0.00           0.02               -0.03
# Salary                           -0.17          -0.09                0.30
# Salaries Reported                -0.07          -0.04                0.04
# Employment Status                -0.10          -0.04                0.03
# Job Roles_Backend                -0.30          -0.21                0.08
# Job Roles_Full stack             -0.46          -0.32               -0.18
# Job Roles_Mobile                  1.00          -0.22                0.02
# Job Roles_Web                    -0.22           1.00                0.14
# Location_Bangalore                0.02           0.14                1.00
# Location_Chennai                 -0.10          -0.02               -0.28
# Location_Hyderabad               -0.10          -0.06               -0.36
# Location_New Delhi                0.16          -0.09               -0.42
# Location_Pune                    -0.02          -0.00               -0.28
#
#                       Location_Chennai  Location_Hyderabad  \
# Rating                            0.01               -0.01
# Salary                           -0.19                0.15
# Salaries Reported                -0.02               -0.00
# Employment Status                -0.03               -0.01
# Job Roles_Backend                 0.15                0.11
# Job Roles_Full stack             -0.02                0.04
# Job Roles_Mobile                 -0.10               -0.10
# Job Roles_Web                    -0.02               -0.06
# Location_Bangalore               -0.28               -0.36
# Location_Chennai                  1.00               -0.17
# Location_Hyderabad               -0.17                1.00
# Location_New Delhi               -0.19               -0.25
# Location_Pune                    -0.13               -0.16
#
#                       Location_New Delhi  Location_Pune
# Rating                              0.03           0.00
# Salary                             -0.26          -0.11
# Salaries Reported                  -0.01          -0.02
# Employment Status                   0.02          -0.02
# Job Roles_Backend                  -0.19          -0.16
# Job Roles_Full stack                0.08           0.15
# Job Roles_Mobile                    0.16          -0.02
# Job Roles_Web                      -0.09          -0.00
# Location_Bangalore                 -0.42          -0.28
# Location_Chennai                   -0.19          -0.13
# Location_Hyderabad                 -0.25          -0.16
# Location_New Delhi                  1.00          -0.19
# Location_Pune                      -0.19           1.00
